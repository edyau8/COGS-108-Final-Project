# %%
# Display plots directly in the notebook instead of in a new window
# %matplotlib inline

# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest
import patsy

# %%
# Loading data from datasets
df_capes = pd.read_csv("CapesCleanedEnrolled.csv")
df_income = pd.read_csv("income_dataset.csv")
df_capes
# Out:
#       Unnamed: 0                 Instructor    Department  Rcmnd Instr  \
# 0              0            Ben-Yosef, Erez  Anthropology   100.000000
# 1              1    D'Alpoim Guedes, Jade A  Anthropology   100.000000
# 2              2  Marchetto, Maria Carolina  Anthropology   100.000000
# 3              3                 Non, Amy L  Anthropology    90.966667
# 4              4       Lew, Caroline Horton  Anthropology    88.100000
# ...          ...                        ...           ...          ...
# 1534        1534          Pafunda, Danielle    Literature    98.075000
# 1535        1535           Johnson, Sara E.    Literature    97.200000
# 1536        1536             Morse, Ainsley    Literature   100.000000
# 1537        1537           Kokotovic, Milos    Literature   100.000000
# 1538        1538                Doller, Ben    Literature    91.700000
#
#       Average Grade Expected  Classes Taught  Enrolled
# 0                     3.6400             1.0      19.0
# 1                     3.7500             1.0      39.0
# 2                     3.9100             1.0      25.0
# 3                     3.2800             3.0      91.0
# 4                     3.6850             2.0      72.0
# ...                      ...             ...       ...
# 1534                  3.8075             4.0     139.0
# 1535                  3.6900             1.0      45.0
# 1536                  3.7000             2.0      30.0
# 1537                  3.7550             2.0      43.0
# 1538                  3.8700             1.0      99.0
#
# [1539 rows x 7 columns]

# %%
# Standardizing the strings in order to combine 
def last_name(string):
    end = string.find(',')
    return string[0:end].upper()

def first_name(string):
    start = string.find(',')
    name = string[start+2:].upper()
    space = name.find(' ')
    if (space != -1):
        return name[:space+2]
    return name

def uppercase(string):
    return string.upper()

def first_name_income(string):
    name = string.upper()
    space = name.find(' ')
    if (space != -1):
        return name[:space+2]
    return name

# %%
# Standardizing Capes Set
df_capes['Last Name'] = df_capes['Instructor'].apply(last_name)
df_capes['First Name'] = df_capes['Instructor'].apply(first_name)
df_capes['Instructor'] = df_capes['Last Name'] + ', ' + df_capes['First Name']

# Standardizing Income Set
df_income['First Name'] = df_income['First Name'].apply(first_name_income)
df_income['Instructor'] = df_income['Last Name'] + ', ' + df_income['First Name']

# %%
# Merge datasets and get rid of merge columns
df = df_income.merge(df_capes, on=['Instructor'])
df = df.drop(['Unnamed: 0_x', 'Last Name_x', 'First Name_x', 'Instructor', 'Unnamed: 0_y', 'Last Name_y', 'First Name_y'], axis=1)
df
# Out:
#                                                   Title  Regular Pay  \
# 0                              LECTURER - ACADEMIC YEAR      40050.0
# 1        LECTURER - ACADEMIC YEAR - ONE OR TWO QUARTERS       8900.0
# 2                 LECTURER - ACADEMIC YEAR - CONTINUING      52200.0
# 3        LECTURER - ACADEMIC YEAR - ONE OR TWO QUARTERS      20767.0
# 4                 LECTURER - ACADEMIC YEAR - CONTINUING     133608.0
# ...                                                 ...          ...
# 1039  PROFESSOR - ACADEMIC YEAR - BUSINESS/ECONOMICS...     202692.0
# 1040                ASSISTANT PROFESSOR - ACADEMIC YEAR      96583.0
# 1041                       VISITING ASSOCIATE PROFESSOR     142222.0
# 1042                          PROFESSOR - ACADEMIC YEAR     142833.0
# 1043                          PROFESSOR - ACADEMIC YEAR     125447.0
#
#                       Department  Rcmnd Instr  Average Grade Expected  \
# 0     Electrical & Computer Eng.    95.120000                3.802000
# 1                     Psychology    97.000000                3.250000
# 2                      Chemistry    90.575000                3.115000
# 3                    Mathematics    90.450000                3.350000
# 4              Education Studies    97.900000                3.980000
# ...                          ...          ...                     ...
# 1039   Rady School of Management    82.200000                3.810000
# 1040                   Chemistry    92.300000                3.125000
# 1041   Rady School of Management    91.216667                3.546667
# 1042                 Mathematics    96.150000                3.210000
# 1043                     Biology    77.350000                3.480000
#
#       Classes Taught  Enrolled
# 0                5.0     196.0
# 1                1.0      52.0
# 2                4.0    1356.0
# 3                2.0     491.0
# 4                1.0      55.0
# ...              ...       ...
# 1039             1.0      52.0
# 1040             2.0     513.0
# 1041             6.0     401.0
# 1042             2.0      43.0
# 1043             2.0     149.0
#
# [1044 rows x 7 columns]

# %% [markdown]
# # Data Analysis

# %%
def standardize_title(string):
    string = str(string)
    string.upper()
    
    if 'LECT' in string:
        return "LECTURER"
    else:
        return "PROFESSOR"

# %%
df['Pay Per Class'] = df['Regular Pay']

df['Title'] = df['Title'].apply(standardize_title)

dfLect = df[df['Title'] == "LECTURER"]
dfProf = df[df['Title'] == "PROFESSOR"]

lower, upper = np.percentile(df['Regular Pay'], [25, 75])
iqr = upper - lower
lower_cutoff = lower - 1.5 * iqr
upper_cutoff = upper + 1.5 * iqr
print("Lower 25: ", lower_cutoff, "\nUpper 25: ", upper_cutoff)

dfLect = (dfLect[(dfLect['Regular Pay'] >= lower_cutoff) & (dfLect['Regular Pay'] <= upper_cutoff)])
df




dfProf['Regular Pay'] = dfProf['Regular Pay'].apply(np.log10)
print(normaltest(dfProf['Regular Pay'].values))


plt.hist(dfProf['Regular Pay'])

dfProf
# Out:
# Lower 25:  -91003.0
# Upper 25:  280765.0
# NormaltestResult(statistic=318.5673138136744, pvalue=6.667864226615867e-70)
# /Users/ericnguyen/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#           Title  Regular Pay                   Department  Rcmnd Instr  \
# 6     PROFESSOR     5.144839             Computer Science    98.620000
# 9     PROFESSOR     5.106449  Mechanical & Aerospace Eng.   100.000000
# 10    PROFESSOR     5.186965                    Economics    95.250000
# 14    PROFESSOR     5.014756                      Biology    98.725000
# 17    PROFESSOR     5.090762   Electrical & Computer Eng.    91.240000
# ...         ...          ...                          ...          ...
# 1039  PROFESSOR     5.306837    Rady School of Management    82.200000
# 1040  PROFESSOR     4.984901                    Chemistry    92.300000
# 1041  PROFESSOR     5.152967    Rady School of Management    91.216667
# 1042  PROFESSOR     5.154829                  Mathematics    96.150000
# 1043  PROFESSOR     5.098460                      Biology    77.350000
#
#       Average Grade Expected  Classes Taught  Enrolled  Pay Per Class
# 6                   3.622000             5.0     657.0       139585.0
# 9                   3.802000             5.0     362.0       127776.0
# 10                  3.415000             2.0     337.0       153803.0
# 14                  3.222500             4.0     356.0       103456.0
# 17                  3.246000             5.0     449.0       123243.0
# ...                      ...             ...       ...            ...
# 1039                3.810000             1.0      52.0       202692.0
# 1040                3.125000             2.0     513.0        96583.0
# 1041                3.546667             6.0     401.0       142222.0
# 1042                3.210000             2.0      43.0       142833.0
# 1043                3.480000             2.0     149.0       125447.0
#
# [724 rows x 8 columns]

# %%
grades = df.sort_values(by=['Average Grade Expected'])['Average Grade Expected']
grades.reset_index(drop=True, inplace=True)
middle = int(grades.size/2)
dividingGrades = grades[middle]

# %%
lowerGrades = []
upperGrades = []

for i in df.index:
    totalPay = df.loc[i, 'pay']
    classes = df.loc[i, 'Classes Taught']
    grade = df.loc[i, 'Average Grade Expected']
    
    pay = totalPay
    
    if grade < dividingGrades:
        lowerGrades.append(pay)
        
    else:
        upperGrades.append(pay)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pay'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-891be535c7e1> in <module>
#       3
#       4 for i in df.index:
# ----> 5     totalPay = df.loc[i, 'pay']
#       6     classes = df.loc[i, 'Classes Taught']
#       7     grade = df.loc[i, 'Average Grade Expected']
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1419                     return section
#    1420                 # This is an elided recursive call to iloc/loc/etc'
# -> 1421                 return getattr(section, self.name)[new_key]
#    1422
#    1423         raise IndexingError("not applicable")
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     619             # but will fail when the index is not present
#     620             # see GH5667
# --> 621             return self.obj._xs(label, axis=axis)
#     622         elif isinstance(label, tuple) and isinstance(label[axis], slice):
#     623             raise IndexingError("no slices here, handle elsewhere")
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'pay'

# %%
sumLower = 0
sumUpper = 0

for i in lowerGrades:
    sumLower += i
    
for i in upperGrades:
    sumUpper += i

averageLower = sumLower/len(lowerGrades)
averageUpper = sumUpper/len(upperGrades)

print(averageLower, averageUpper)

# %%
print(normaltest(lowerGrades))
print(normaltest(upperGrades))

# %%
ttest_ind(lowerGrades, upperGrades)

# %%
rcmnd = df.sort_values(by=['Rcmnd Instr'])['Rcmnd Instr']
rcmnd.reset_index(drop=True, inplace=True)
middle = int(len(rcmnd)/2)
dividingRcmnd = rcmnd[middle]

# %%
lowerRcmnd = []
upperRcmnd = []

for i in df.index:
    totalPay = df.loc[i, 'Regular Pay']
    classes = df.loc[i, 'Classes Taught']
    rec = df.loc[i, 'Rcmnd Instr']
    
    pay = totalPay/classes
    
    if rec < dividingRcmnd:
        lowerRcmnd.append(pay)
        
    else:
        upperRcmnd.append(pay)

# %%
print(len(lowerRcmnd))
print(len(upperRcmnd))

# %%
sumLower = 0
sumUpper = 0

for i in lowerRcmnd:
    sumLower += i
    
for i in upperRcmnd:
    sumUpper += i

averageLower = sumLower/len(lowerRcmnd)
averageUpper = sumUpper/len(upperRcmnd)

print(averageLower, averageUpper)

# %%
print(normaltest(lowerRcmnd))
print(normaltest(upperRcmnd))

# %%
ttest_ind(lowerRcmnd, upperRcmnd)
