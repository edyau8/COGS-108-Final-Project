# %%
# Imports 
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest
# Note: the statsmodels import may print out a 'FutureWarning'. Thats fine.

# %%
df = pd.read_csv('income_data/income_final.csv')
df = df.set_index('Unnamed: 0')
df = df.reset_index(drop=True)
df
# Out:
#       Last Name       First Name  \
# 0     ABI SAMRA  NICHOLAS CAMILL
# 1     ACCOMANDO   ALYSSA WHEELER
# 2         ADAMS     DAVE KENNETH
# 3        AGUILA      CHRISTINA O
# 4           AJO   FRANCES BERGEN
# ...         ...              ...
# 3385     ZLATOS           ANDREJ
# 3386  ZLOMISLIC            VINKO
# 3387        ZOU            YIMIN
# 3388     ZUNIGA          ELINA I
# 3389      ZURAW    BRUCE LEONARD
#
#                                                   Title  Regular Pay
# 0                              LECTURER - ACADEMIC YEAR      40050.0
# 1        LECTURER - ACADEMIC YEAR - ONE OR TWO QUARTERS       8900.0
# 2                            LECTURER IN SUMMER SESSION          0.0
# 3        LECTURER - ACADEMIC YEAR - ONE OR TWO QUARTERS       5874.0
# 4                              LECTURER - ACADEMIC YEAR      53959.0
# ...                                                 ...          ...
# 3385                          PROFESSOR - ACADEMIC YEAR     142833.0
# 3386  HEALTH SCIENCES ASSISTANT CLINICAL PROFESSOR -...     138950.0
# 3387                          PROFESSOR - ACADEMIC YEAR     160025.0
# 3388                          PROFESSOR - ACADEMIC YEAR     125447.0
# 3389                                  PROFESSOR - HCOMP     168606.0
#
# [3390 rows x 4 columns]

# %%
df = df[df['Regular Pay'] != 0.0]
df
# Out:
#       Last Name       First Name  \
# 0     ABI SAMRA  NICHOLAS CAMILL
# 1     ACCOMANDO   ALYSSA WHEELER
# 3        AGUILA      CHRISTINA O
# 4           AJO   FRANCES BERGEN
# 5        AKJEJE         ABDELHAK
# ...         ...              ...
# 3385     ZLATOS           ANDREJ
# 3386  ZLOMISLIC            VINKO
# 3387        ZOU            YIMIN
# 3388     ZUNIGA          ELINA I
# 3389      ZURAW    BRUCE LEONARD
#
#                                                   Title  Regular Pay
# 0                              LECTURER - ACADEMIC YEAR      40050.0
# 1        LECTURER - ACADEMIC YEAR - ONE OR TWO QUARTERS       8900.0
# 3        LECTURER - ACADEMIC YEAR - ONE OR TWO QUARTERS       5874.0
# 4                              LECTURER - ACADEMIC YEAR      53959.0
# 5                 LECTURER - ACADEMIC YEAR - CONTINUING      68012.0
# ...                                                 ...          ...
# 3385                          PROFESSOR - ACADEMIC YEAR     142833.0
# 3386  HEALTH SCIENCES ASSISTANT CLINICAL PROFESSOR -...     138950.0
# 3387                          PROFESSOR - ACADEMIC YEAR     160025.0
# 3388                          PROFESSOR - ACADEMIC YEAR     125447.0
# 3389                                  PROFESSOR - HCOMP     168606.0
#
# [3316 rows x 4 columns]

# %%
df
# Out:
#       Last Name       First Name  \
# 0     ABI SAMRA  NICHOLAS CAMILL
# 1     ACCOMANDO   ALYSSA WHEELER
# 3        AGUILA      CHRISTINA O
# 4           AJO   FRANCES BERGEN
# 5        AKJEJE         ABDELHAK
# ...         ...              ...
# 3385     ZLATOS           ANDREJ
# 3386  ZLOMISLIC            VINKO
# 3387        ZOU            YIMIN
# 3388     ZUNIGA          ELINA I
# 3389      ZURAW    BRUCE LEONARD
#
#                                                   Title  Regular Pay
# 0                              LECTURER - ACADEMIC YEAR      40050.0
# 1        LECTURER - ACADEMIC YEAR - ONE OR TWO QUARTERS       8900.0
# 3        LECTURER - ACADEMIC YEAR - ONE OR TWO QUARTERS       5874.0
# 4                              LECTURER - ACADEMIC YEAR      53959.0
# 5                 LECTURER - ACADEMIC YEAR - CONTINUING      68012.0
# ...                                                 ...          ...
# 3385                          PROFESSOR - ACADEMIC YEAR     142833.0
# 3386  HEALTH SCIENCES ASSISTANT CLINICAL PROFESSOR -...     138950.0
# 3387                          PROFESSOR - ACADEMIC YEAR     160025.0
# 3388                          PROFESSOR - ACADEMIC YEAR     125447.0
# 3389                                  PROFESSOR - HCOMP     168606.0
#
# [3316 rows x 4 columns]

# %%
df.to_csv('income_dataset.csv')
